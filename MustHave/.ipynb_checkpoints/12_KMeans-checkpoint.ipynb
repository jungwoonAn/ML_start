# %% [markdown]
# # 12.1 문제 정의
# 데이터들을 비슷한 속성끼리 분류하라.
#
# 여기에서는 2개의 데이터를 사용합니다. 첫번째 데이터는 K-평균 군집화를 학습할 목적으로 인위적으로 만든 데이터로, 변수들에는 아무런 의미가 없습니다. 두번째 데이터는 11장에서 사용한 데이터 중 일부 변수와 일부 고객 정보만을 포함합니다.

# %% [markdown]
# ## 12.2 K-평균 군집화 맛보기 : 인위적으로 만든 데이터셋

# %% [markdown]
# ### 12.2.1 라이브러리 및 연습용 데이터 불러오기, 데이터 확인하기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

file_url = 'https://raw.githubusercontent.com/snkn1959/data_source/main/example_cluster.csv'
data = pd.read_csv(file_url)

# %%
data
# Out:
#          var_1     var_2
# 0     3.264413  6.929164
# 1     0.220814  2.251631
# 2    -8.786197 -8.333582
# 3    -0.008547  2.630791
# 4     4.912903  6.888520
# ..         ...       ...
# 995   4.678232  7.704404
# 996   5.250715  6.930948
# 997 -11.818752 -5.609853
# 998   0.613725  3.809334
# 999   3.516961  8.486305
#
# [1000 rows x 2 columns]

# %%
# 산점도 그리기
sns.scatterplot(x='var_1', y = 'var_2', data= data)
# Out:
# <Axes: xlabel='var_1', ylabel='var_2'>

# %% [markdown]
# ### 12.2.2 연습용 데이터 모델링 및 평가

# %%
from sklearn.cluster import KMeans

# %%
# 모델 객체 생성
kmeans_model = KMeans(n_clusters=3, random_state = 100)

# %%
# 학습
kmeans_model.fit(data)
# Out:
# KMeans(n_clusters=3, random_state=100)

# %%
# 예측
kmeans_model.predict(data)
# Out:
# array([2, 1, 0, 1, 2, 1, 2, 0, 2, 2, 2, 2, 1, 2, 0, 1, 0, 2, 2, 0, 1, 0,
#        0, 0, 1, 2, 1, 0, 1, 1, 1, 0, 1, 2, 2, 0, 0, 2, 2, 2, 1, 1, 2, 1,
#        0, 2, 2, 1, 0, 1, 2, 0, 2, 1, 2, 0, 0, 0, 1, 1, 1, 2, 1, 2, 0, 2,
#        1, 0, 2, 0, 1, 2, 1, 1, 1, 1, 2, 1, 1, 1, 2, 1, 0, 1, 2, 2, 1, 2,
#        0, 1, 2, 1, 0, 1, 0, 0, 0, 2, 1, 1, 1, 0, 0, 1, 0, 2, 0, 0, 0, 2,
#        0, 1, 2, 1, 1, 1, 0, 1, 0, 0, 2, 2, 1, 0, 1, 0, 1, 0, 2, 2, 0, 2,
#        1, 2, 0, 2, 1, 1, 1, 2, 1, 2, 0, 0, 1, 2, 0, 1, 1, 2, 2, 1, 1, 2,
#        2, 2, 1, 0, 2, 0, 2, 1, 2, 0, 0, 2, 1, 2, 0, 2, 1, 2, 0, 2, 2, 0,
#        1, 2, 0, 1, 1, 0, 1, 1, 2, 2, 2, 1, 2, 0, 1, 1, 1, 0, 2, 1, 1, 1,
#        2, 2, 2, 1, 1, 1, 2, 0, 1, 1, 1, 0, 0, 2, 1, 2, 1, 0, 0, 2, 1, 0,
#        1, 1, 0, 2, 0, 0, 2, 0, 2, 1, 0, 2, 2, 0, 0, 0, 2, 2, 2, 0, 1, 0,
#        2, 0, 0, 2, 1, 0, 2, 2, 0, 2, 1, 0, 2, 1, 0, 0, 1, 0, 2, 0, 2, 1,
#        1, 1, 0, 2, 1, 2, 2, 2, 2, 0, 2, 0, 1, 1, 2, 0, 1, 0, 2, 0, 1, 1,
# ...

# %%
# 예측값을 label로 저장
data['label'] = kmeans_model.predict(data)

# %%
# 산점도 그리기
sns.scatterplot(x='var_1', y = 'var_2', data= data, hue='label', palette='rainbow')
# Out:
# <Axes: xlabel='var_1', ylabel='var_2'>

# %% [markdown]
# ### 12.2.3 엘보우 기법으로 최적의 K값 구하기
# - 엘보우 기법(elbow method)
#   : 최적의 클러스터 개수를 확인하는 방법으로, 클러스터의 중점과 각 데이터 간의 거리를 기반으로 계산합니다.(distance가 급격히 줄어드는 K값을 포착하여 최적의 K값을 찾도록 도와주는 방법론)
#
# - 이너셔(inertia)
#   : 각 그룹에서의 중심과 각 그룹에 해당하는 데이터 간의 거리에 대한 합

# %%
# 이니셔 확인
kmeans_model.inertia_
# Out:
# 3090.033237076661

# %%
temp_model = KMeans(n_clusters=500, random_state = 100)
temp_model.fit(data)
temp_model.inertia_
# Out:
# 6.341205909239223

# %%
distance = []   # ❶ 빈 리스트 생성
for k in range(2,10):
    k_model = KMeans(n_clusters=k)
    k_model.fit(data)    
    distance.append(k_model.inertia_) # ❷ 이니셔를 리스트에 저장

# %%
distance  # 저장된 이니셔 확인
# Out:
# [9908.551424778394,
#  3090.033237076661,
#  2753.1524529258995,
#  2428.7212880770576,
#  2197.4150512828746,
#  1861.1566250772466,
#  1737.6492170586437,
#  1374.12514264415]

# %%
# 엘보우 플랏 그리기
sns.lineplot(x=range(2,10), y=distance)
# Out:
# <Axes: >

# %% [markdown]
# ## 12.3 데이터 불러오기 및 데이터 확인하기 : 고객 데이터셋

# %%
file_url = 'https://raw.githubusercontent.com/snkn1959/data_source/main/customer.csv'
customer = pd.read_csv(file_url)

# %%
customer.head()
# Out:
#              cc_num       category     amt
# 0  2703186189652095           misc    4.97
# 1      630423337322        grocery  107.23
# 2    38859492057661  entertainment  220.11
# 3  3534093764340240  gas_transport   45.00
# 4   375534208663984           misc   41.96

# %%
# 카드번호의 고윳값 확인
customer['cc_num'].nunique()
# Out:
# 100

# %%
# 카테고리의 고윳값 확인
customer['category'].nunique()
# Out:
# 11

# %% [markdown]
# ## 12.4 전처리 : 피처 엔지니어링

# %%
# 카테고리를 더미 변수로 변환
customer_dummy = pd.get_dummies(customer, columns =['category'])

# %%
customer_dummy.head()
# Out:
#              cc_num     amt  category_entertainment  category_food_dining  \
# 0  2703186189652095    4.97                   False                 False
# 1      630423337322  107.23                   False                 False
# 2    38859492057661  220.11                    True                 False
# 3  3534093764340240   45.00                   False                 False
# 4   375534208663984   41.96                   False                 False
#
#    category_gas_transport  category_grocery  category_health_fitness  \
# 0                   False             False                    False
# 1                   False              True                    False
# 2                   False             False                    False
# 3                    True             False                    False
# 4                   False             False                    False
#
#    category_home  category_kids_pets  category_misc  category_personal_care  \
# ...

# %%
# 변수 이름 리스트 생성
cat_list = customer_dummy.columns[2:]

# %%
# 금액으로 변수 업데이트
for i in cat_list:
    customer_dummy[i] = customer_dummy[i] * customer_dummy['amt']

# %%
customer_dummy
# Out:
#                   cc_num     amt  category_entertainment  \
# 0       2703186189652095    4.97                    0.00
# 1           630423337322  107.23                    0.00
# 2         38859492057661  220.11                  220.11
# 3       3534093764340240   45.00                    0.00
# 4        375534208663984   41.96                    0.00
# ...                  ...     ...                     ...
# 240449  4716561796955522    4.93                    0.00
# 240450    30074693890476  140.12                    0.00
# 240451    30404291151692   37.79                    0.00
# 240452  4922710831011201   17.50                   17.50
# 240453   213112402583773   25.49                    0.00
#
#         category_food_dining  category_gas_transport  category_grocery  \
# 0                        0.0                     0.0              0.00
# 1                        0.0                     0.0            107.23
# ...

# %%
# cc_num별 총 금액
customer_agg = customer_dummy.groupby('cc_num').sum()

# %%
customer_agg.head()
# Out:
#                     amt  category_entertainment  category_food_dining  \
# cc_num
# 60495593109    48149.62                 3169.74               4043.46
# 571365235126  259784.87                13864.51               9055.51
# 571465035400  270081.63                16162.98              15448.75
# 630412733309   41959.52                 3212.46               1543.16
# 630423337322  244612.73                12786.75               6905.07
#
#               category_gas_transport  category_grocery  \
# cc_num
# 60495593109                  5076.36           7576.58
# 571365235126                36525.79          48812.73
# 571465035400                 9081.62          41643.82
# 630412733309                 5786.98           8416.70
# 630423337322                36460.40          43854.26
#
#               category_health_fitness  category_home  category_kids_pets  \
# cc_num
# 60495593109                   1631.22        5458.58             4924.97
# ...

# %%
# 스케일링
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler() # ❶ 스케일러 객체 생성
scaled_df = pd.DataFrame(scaler.fit_transform(customer_agg), # ❷ 데이터 프레임 형태로 변환
            columns = customer_agg.columns, # ❸ 데이터프레임 컬럼 이름 정의
            index=customer_agg.index) # ❹ 데이터프레임 인덱스 이름 정의

# %%
scaled_df.head()
# Out:
#                    amt  category_entertainment  category_food_dining  \
# cc_num
# 60495593109  -1.402327               -1.135617             -0.971069
# 571365235126  1.079407                0.414075              0.168880
# 571465035400  1.200151                0.747127              1.622968
# 630412733309 -1.474915               -1.129427             -1.539741
# 630423337322  0.901491                0.257905             -0.320220
#
#               category_gas_transport  category_grocery  \
# cc_num
# 60495593109                -1.000180         -1.118217
# 571365235126                2.090013          0.767268
# 571465035400               -0.606627          0.439476
# 630412733309               -0.930355         -1.079803
# 630423337322                2.083588          0.540547
#
#               category_health_fitness  category_home  category_kids_pets  \
# cc_num
# 60495593109                 -1.561756      -1.145051           -1.276913
# ...

# %% [markdown]
# ## 12.5 고객 데이터 모델링 및 실루엣 계수

# %%
distance = []
for k in range(2,10):
    k_model = KMeans(n_clusters=k)  # 모델 객체 생성
    k_model.fit(scaled_df)  # 학습
    labels = k_model.predict(scaled_df)  # 예측
    distance.append(k_model.inertia_)  # 이너셔값 리스트에 추가

sns.lineplot(x=range(2,10), y=distance)  # 엘보우 플랏 그리기
# Out:
# c:\Users\m11\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\m11\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\m11\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %% [markdown]
# - 실루엣 계수(silhouette coefficient)
#   : 엘보우 기법과 같이 최적의 클러스터 수를 찾는 방법으로, 엘보우 기법에서 적절한 클러스터 수를 찾지 못했을 때 대안으로 사용할 수 있습니다. 엘보우 기법보다 계산 시간이 오래 걸리는 단점이 있습니다.

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette = []
for k in range(2,10):
    k_model = KMeans(n_clusters=k)
    k_model.fit(scaled_df)
    labels = k_model.predict(scaled_df)
    silhouette.append(silhouette_score(scaled_df, labels))  # 실루엣 계수 리스트에 추가
# Out:
# c:\Users\m11\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\m11\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\m11\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
sns.lineplot(x=range(2,10), y=silhouette)  # 선형 그래프 그리기
# 실루엣 계수는 높은 값일 수록 더 좋은 분류를 의미
# Out:
# <Axes: >

# %% [markdown]
# ## 12.6 최종 예측 모델 및 결과 해석

# %%
k_model = KMeans(n_clusters=4)
k_model.fit(scaled_df)
labels = k_model.predict(scaled_df)
# Out:
# c:\Users\m11\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# label변수 정의
scaled_df['label'] = labels

# %%
scaled_df_mean = scaled_df.groupby('label').mean() # ❶ label별 평균값
scaled_df_count = scaled_df.groupby('label').count()['category_travel'] # ❷ label별 등장 횟수

# %%
scaled_df_count = scaled_df_count.rename('count')  # 이름 변경

# %%
scaled_df_all = scaled_df_mean.join(scaled_df_count)  # 데이터 합치기

# %%
scaled_df_all  # 완선된 데이터 출력
# Out:
#             amt  category_entertainment  category_food_dining  \
# label
# 0     -0.858082               -0.739555             -0.758078
# 1      0.372023                0.215463              0.277615
# 2      2.246930                2.636017              2.102489
# 3      1.000533                0.776166              1.036432
#
#        category_gas_transport  category_grocery  category_health_fitness  \
# label
# 0                   -0.601061         -0.653905                -0.837854
# 1                    0.885459          0.226599                 0.440311
# 2                   -0.339554          2.553883                 1.526188
# 3                   -0.749213          0.310577                 1.175961
#
#        category_home  category_kids_pets  category_misc  \
# label
# 0          -0.832432           -0.866100      -0.701383
# 1           0.381802            0.709355       0.429554
# 2           1.118452            1.527483       2.410239
# ...
